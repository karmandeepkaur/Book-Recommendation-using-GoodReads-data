# %%
import gzip 
with gzip.open("goodreads_books.json.gz", "r") as f:
    line = f.readline()

line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
import json

json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %% [markdown]
# ### Parsing our Book Metadata
#
# > This function essentially filters the information from the original JSON data, keeping only the fields specified in the return statement. It can be useful when you want to simplify or extract specific information from a larger dataset.

# %%
def parse_feilds(line):
    # Parse the JSON-formatted string into a Python dictionary
    data = json.loads(line)

    # Create a new dictionary with selected fields
    return {
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings" : data["ratings_count"],
        "url" : data["url"],
        "cover_image" : data["image_url"]
    }

# %% [markdown]
# - This code reads lines from a gzipped JSON file ("goodreads_books.json.gz"), parsing each line using the parse_feilds function, and then filtering out books with ratings less than or equal to 15. The resulting book information (title, book_id, etc.) for books with ratings greater than 150 is stored in the books_titles list.

# %%
 # Initialize an empty list to store book information

books_titles = []
with gzip.open("goodreads_books.json.gz", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        feilds = parse_feilds(line)

        try: 
            ratings = int(feilds["ratings"])
        except ValueError:
            continue


        # Check if the ratings are greater than 150
        if ratings > 150:
            books_titles.append(feilds)

# %% [markdown]
# ### Processing Book Metadata with Pandas

# %%
import pandas as pd

# creating DataFrame from a list of books with more than 150 ratings
titles = pd.DataFrame.from_dict(books_titles)

# %%
titles["ratings"] = pd.to_numeric(titles["ratings"])

#  "mod_title," which contains modified versions of the "title" column with non-alphanumeric characters removed. 
titles["mod_title"] = titles["title"].str.replace("[^a-zA-z0-9 ]", "", regex = True)
titles
# Out:
#          book_id                                              title  ratings  \
# 0        6066819                               Best Friends Forever    51184
# 1         287149                               The Devil's Notebook      986
# 2        6066814          Crowner Royal (Crowner John Mystery, #13)      186
# 3       33394837            The House of Memory (Pluto's Snitch #2)      269
# 4          89375  90 Minutes in Heaven: A True Story of Death an...    68157
# ...          ...                                                ...      ...
# 381185  17280727                                       دولة البطاطس      151
# 381186  31522515                                Walking on My Grave      340
# 381187  15500943                Not Quickly Broken (Chop, Chop, #7)      456
# 381188   1370179             The Brazilian Boss's Innocent Mistress      240
# 381189  17805813                      Ondine (Ondine Quartet, #0.5)      327
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/6066819-be...
# 1       https://www.goodreads.com/book/show/287149.The...
# 2       https://www.goodreads.com/book/show/6066814-cr...
# 3       https://www.goodreads.com/book/show/33394837-t...
# 4       https://www.goodreads.com/book/show/89375.90_M...
# ...                                                   ...
# 381185       https://www.goodreads.com/book/show/17280727
# 381186  https://www.goodreads.com/book/show/31522515-w...
# 381187  https://www.goodreads.com/book/show/15500943-n...
# 381188  https://www.goodreads.com/book/show/1370179.Th...
# 381189  https://www.goodreads.com/book/show/17805813-o...
#
#                                               cover_image  \
# 0       https://s.gr-assets.com/assets/nophoto/book/11...
# 1       https://images.gr-assets.com/books/1328768789m...
# 2       https://images.gr-assets.com/books/1328724803m...
# 3       https://images.gr-assets.com/books/1493114742m...
# 4       https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                   ...
# 381185  https://images.gr-assets.com/books/1358953155m...
# 381186  https://images.gr-assets.com/books/1490374478m...
# 381187  https://images.gr-assets.com/books/1381765124m...
# 381188  https://s.gr-assets.com/assets/nophoto/book/11...
# 381189  https://images.gr-assets.com/books/1379766592m...
#
#                                                 mod_title
# 0                                    Best Friends Forever
# 1                                     The Devils Notebook
# 2                   Crowner Royal Crowner John Mystery 13
# 3                     The House of Memory Plutos Snitch 2
# 4       90 Minutes in Heaven A True Story of Death and...
# ...                                                   ...
# 381185
# 381186                                Walking on My Grave
# 381187                     Not Quickly Broken Chop Chop 7
# 381188              The Brazilian Bosss Innocent Mistress
# 381189                           Ondine Ondine Quartet 05
#
# [381190 rows x 6 columns]

# %%
titles["mod_title"] = titles["mod_title"].str.lower()

# Filter out all the trailing white spaces
titles["mod_title"] = titles["mod_title"].str.replace("\s+", " ", regex = True)
titles
# Out:
#          book_id                                              title  ratings  \
# 0        6066819                               Best Friends Forever    51184
# 1         287149                               The Devil's Notebook      986
# 2        6066814          Crowner Royal (Crowner John Mystery, #13)      186
# 3       33394837            The House of Memory (Pluto's Snitch #2)      269
# 4          89375  90 Minutes in Heaven: A True Story of Death an...    68157
# ...          ...                                                ...      ...
# 381185  17280727                                       دولة البطاطس      151
# 381186  31522515                                Walking on My Grave      340
# 381187  15500943                Not Quickly Broken (Chop, Chop, #7)      456
# 381188   1370179             The Brazilian Boss's Innocent Mistress      240
# 381189  17805813                      Ondine (Ondine Quartet, #0.5)      327
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/6066819-be...
# 1       https://www.goodreads.com/book/show/287149.The...
# 2       https://www.goodreads.com/book/show/6066814-cr...
# 3       https://www.goodreads.com/book/show/33394837-t...
# 4       https://www.goodreads.com/book/show/89375.90_M...
# ...                                                   ...
# 381185       https://www.goodreads.com/book/show/17280727
# 381186  https://www.goodreads.com/book/show/31522515-w...
# 381187  https://www.goodreads.com/book/show/15500943-n...
# 381188  https://www.goodreads.com/book/show/1370179.Th...
# 381189  https://www.goodreads.com/book/show/17805813-o...
#
#                                               cover_image  \
# 0       https://s.gr-assets.com/assets/nophoto/book/11...
# 1       https://images.gr-assets.com/books/1328768789m...
# 2       https://images.gr-assets.com/books/1328724803m...
# 3       https://images.gr-assets.com/books/1493114742m...
# 4       https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                   ...
# 381185  https://images.gr-assets.com/books/1358953155m...
# 381186  https://images.gr-assets.com/books/1490374478m...
# 381187  https://images.gr-assets.com/books/1381765124m...
# 381188  https://s.gr-assets.com/assets/nophoto/book/11...
# 381189  https://images.gr-assets.com/books/1379766592m...
#
#                                                 mod_title
# 0                                    best friends forever
# 1                                     the devils notebook
# 2                   crowner royal crowner john mystery 13
# 3                     the house of memory plutos snitch 2
# 4       90 minutes in heaven a true story of death and...
# ...                                                   ...
# 381185
# 381186                                walking on my grave
# 381187                     not quickly broken chop chop 7
# 381188              the brazilian bosss innocent mistress
# 381189                           ondine ondine quartet 05
#
# [381190 rows x 6 columns]

# %%
# Filter out empty files
titles = titles[titles["mod_title"].str.len() > 0]

# saving it all in a JSON file
titles.to_json("books_titles.json")
titles
# Out:
#          book_id                                              title  ratings  \
# 0        6066819                               Best Friends Forever    51184
# 1         287149                               The Devil's Notebook      986
# 2        6066814          Crowner Royal (Crowner John Mystery, #13)      186
# 3       33394837            The House of Memory (Pluto's Snitch #2)      269
# 4          89375  90 Minutes in Heaven: A True Story of Death an...    68157
# ...          ...                                                ...      ...
# 381185  17280727                                       دولة البطاطس      151
# 381186  31522515                                Walking on My Grave      340
# 381187  15500943                Not Quickly Broken (Chop, Chop, #7)      456
# 381188   1370179             The Brazilian Boss's Innocent Mistress      240
# 381189  17805813                      Ondine (Ondine Quartet, #0.5)      327
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/6066819-be...
# 1       https://www.goodreads.com/book/show/287149.The...
# 2       https://www.goodreads.com/book/show/6066814-cr...
# 3       https://www.goodreads.com/book/show/33394837-t...
# 4       https://www.goodreads.com/book/show/89375.90_M...
# ...                                                   ...
# 381185       https://www.goodreads.com/book/show/17280727
# 381186  https://www.goodreads.com/book/show/31522515-w...
# 381187  https://www.goodreads.com/book/show/15500943-n...
# 381188  https://www.goodreads.com/book/show/1370179.Th...
# 381189  https://www.goodreads.com/book/show/17805813-o...
#
#                                               cover_image  \
# 0       https://s.gr-assets.com/assets/nophoto/book/11...
# 1       https://images.gr-assets.com/books/1328768789m...
# 2       https://images.gr-assets.com/books/1328724803m...
# 3       https://images.gr-assets.com/books/1493114742m...
# 4       https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                   ...
# 381185  https://images.gr-assets.com/books/1358953155m...
# 381186  https://images.gr-assets.com/books/1490374478m...
# 381187  https://images.gr-assets.com/books/1381765124m...
# 381188  https://s.gr-assets.com/assets/nophoto/book/11...
# 381189  https://images.gr-assets.com/books/1379766592m...
#
#                                                 mod_title
# 0                                    best friends forever
# 1                                     the devils notebook
# 2                   crowner royal crowner john mystery 13
# 3                     the house of memory plutos snitch 2
# 4       90 minutes in heaven a true story of death and...
# ...                                                   ...
# 381185
# 381186                                walking on my grave
# 381187                     not quickly broken chop chop 7
# 381188              the brazilian bosss innocent mistress
# 381189                           ondine ondine quartet 05
#
# [379878 rows x 6 columns]

# %% [markdown]
# ### Building A Search Engine

# %% [markdown]
# - TfidfVectorizer is a tool for converting a collection of raw documents (in this case, titles) into a matrix of TF-IDF features.
# - Each row of the matrix corresponds to a title, and each column corresponds to a unique word in the titles. The values in the matrix represent the TF-IDF scores for each word in each title.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["mod_title"])

tfidf
# Out:
# <379878x92395 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1809158 stored elements in Compressed Sparse Row format>

# %%
liked_books = []

# %% [markdown]
# >  displays the top 5 results in a styled Pandas DataFrame with clickable URLs and images.
#
# - Cosine similarity is a measure of similarity between two non-zero vectors in an inner product space. cosine similarity is often used to measure the similarity between two documents or text passages. It calculates the cosine of the angle between two vectors and ranges from -1 (completely dissimilar) to 1 (completely similar).

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np 
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search(query, vectorizer):
    # cleaning the query
    query = query.lower()
    pro = re.sub("[^a-zA-Z0-9]", "", query)
    # turning the query into a tf - idf vector
    query_vec = vectorizer.transform([query])

    similarity = cosine_similarity(query_vec, tfidf).flatten()

    indices = np.argpartition(similarity, -10)[-10:]
    result = titles.iloc[indices]

    # show the book with the highest rating first
    result = result.sort_values("ratings", ascending=False)
    
    liked_books.append(result.iloc[0]["book_id"])


    
    return result.head(5).style.format({'cover_image' : show_image, 'url': make_clickable})

# %%
search("northanger abbey", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_66f43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66f43_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_66f43_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_66f43_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_66f43_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_66f43_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_66f43_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66f43_level0_row0" class="row_heading level0 row0" >262657</th>
#       <td id="T_66f43_row0_col0" class="data row0 col0" >398199</td>
#       <td id="T_66f43_row0_col1" class="data row0 col1" >Northanger Abbey</td>
#       <td id="T_66f43_row0_col2" class="data row0 col2" >2436</td>
#       <td id="T_66f43_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/398199.Northanger_Abbey">Goodreads</a></td>
#       <td id="T_66f43_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1320451066m/398199.jpg" width=50></img></td>
#       <td id="T_66f43_row0_col5" class="data row0 col5" >northanger abbey</td>
#     </tr>
#     <tr>
#       <th id="T_66f43_level0_row1" class="row_heading level0 row1" >119649</th>
#       <td id="T_66f43_row1_col0" class="data row1 col0" >6234197</td>
#       <td id="T_66f43_row1_col1" class="data row1 col1" >Northanger Abbey</td>
#       <td id="T_66f43_row1_col2" class="data row1 col2" >2248</td>
#       <td id="T_66f43_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/6234197-northanger-abbey">Goodreads</a></td>
#       <td id="T_66f43_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1329447394m/6234197.jpg" width=50></img></td>
#       <td id="T_66f43_row1_col5" class="data row1 col5" >northanger abbey</td>
#     </tr>
#     <tr>
#       <th id="T_66f43_level0_row2" class="row_heading level0 row2" >203631</th>
#       <td id="T_66f43_row2_col0" class="data row2 col0" >8144727</td>
#       <td id="T_66f43_row2_col1" class="data row2 col1" >Northanger Abbey</td>
#       <td id="T_66f43_row2_col2" class="data row2 col2" >745</td>
#       <td id="T_66f43_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/8144727-northanger-abbey">Goodreads</a></td>
#       <td id="T_66f43_row2_col4" class="data row2 col4" ><img src="https://images.gr-assets.com/books/1352038237m/8144727.jpg" width=50></img></td>
#       <td id="T_66f43_row2_col5" class="data row2 col5" >northanger abbey</td>
#     </tr>
#     <tr>
#       <th id="T_66f43_level0_row3" class="row_heading level0 row3" >6052</th>
#       <td id="T_66f43_row3_col0" class="data row3 col0" >11758567</td>
#       <td id="T_66f43_row3_col1" class="data row3 col1" >Northanger Abbey</td>
#       <td id="T_66f43_row3_col2" class="data row3 col2" >622</td>
#       <td id="T_66f43_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/11758567-northanger-abbey">Goodreads</a></td>
#       <td id="T_66f43_row3_col4" class="data row3 col4" ><img src="https://images.gr-assets.com/books/1502779514m/11758567.jpg" width=50></img></td>
#       <td id="T_66f43_row3_col5" class="data row3 col5" >northanger abbey</td>
#     </tr>
#     <tr>
#       <th id="T_66f43_level0_row4" class="row_heading level0 row4" >131364</th>
#       <td id="T_66f43_row4_col0" class="data row4 col0" >827523</td>
#       <td id="T_66f43_row4_col1" class="data row4 col1" >Northanger Abbey</td>
#       <td id="T_66f43_row4_col2" class="data row4 col2" >594</td>
#       <td id="T_66f43_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show
row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2947880-jane-eyre">Goodreads</a></td>
#       <td id="T_ebb1e_row4_col4" class="data row4 col4" ><img src="https://images.gr-assets.com/books/1335192454m/2947880.jpg" width=50></img></td>
#       <td id="T_ebb1e_row4_col5" class="data row4 col5" >jane eyre</td>
#     </tr>
#   </tbody>
# </table>

# %%
search("far from the madding crowd", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcb0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcb0a_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_fcb0a_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_fcb0a_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_fcb0a_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_fcb0a_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_fcb0a_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb0a_level0_row0" class="row_heading level0 row0" >370721</th>
#       <td id="T_fcb0a_row0_col0" class="data row0 col0" >31463</td>
#       <td id="T_fcb0a_row0_col1" class="data row0 col1" >Far from the Madding Crowd</td>
#       <td id="T_fcb0a_row0_col2" class="data row0 col2" >89085</td>
#       <td id="T_fcb0a_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/31463.Far_from_the_Madding_Crowd">Goodreads</a></td>
#       <td id="T_fcb0a_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1388279695m/31463.jpg" width=50></img></td>
#       <td id="T_fcb0a_row0_col5" class="data row0 col5" >far from the madding crowd</td>
#     </tr>
#     <tr>
#       <th id="T_fcb0a_level0_row1" class="row_heading level0 row1" >28705</th>
#       <td id="T_fcb0a_row1_col0" class="data row1 col0" >14800528</td>
#       <td id="T_fcb0a_row1_col1" class="data row1 col1" >Far from the Madding Crowd</td>
#       <td id="T_fcb0a_row1_col2" class="data row1 col2" >521</td>
#       <td id="T_fcb0a_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/14800528-far-from-the-madding-crowd">Goodreads</a></td>
#       <td id="T_fcb0a_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1400007632m/14800528.jpg" width=50></img></td>
#       <td id="T_fcb0a_row1_col5" class="data row1 col5" >far from the madding crowd</td>
#     </tr>
#     <tr>
#       <th id="T_fcb0a_level0_row2" class="row_heading level0 row2" >370722</th>
#       <td id="T_fcb0a_row2_col0" class="data row2 col0" >31462</td>
#       <td id="T_fcb0a_row2_col1" class="data row2 col1" >Far from the Madding Crowd</td>
#       <td id="T_fcb0a_row2_col2" class="data row2 col2" >334</td>
#       <td id="T_fcb0a_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/31462.Far_from_the_Madding_Crowd">Goodreads</a></td>
#       <td id="T_fcb0a_row2_col4" class="data row2 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_fcb0a_row2_col5" class="data row2 col5" >far from the madding crowd</td>
#     </tr>
#     <tr>
#       <th id="T_fcb0a_level0_row3" class="row_heading level0 row3" >202580</th>
#       <td id="T_fcb0a_row3_col0" class="data row3 col0" >929547</td>
#       <td id="T_fcb0a_row3_col1" class="data row3 col1" >Far From the Madding Crowd</td>
#       <td id="T_fcb0a_row3_col2" class="data row3 col2" >283</td>
#       <td id="T_fcb0a_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show
row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/23234844-the-black">Goodreads</a></td>
#       <td id="T_3d992_row4_col4" class="data row4 col4" ><img src="https://images.gr-assets.com/books/1412105499m/23234844.jpg" width=50></img></td>
#       <td id="T_3d992_row4_col5" class="data row4 col5" >the black</td>
#     </tr>
#   </tbody>
# </table>

# %%
liked_books
# Out:
# ['398199', '50165', '31463', '14662']

# %% [markdown]
# ### Exploring the Book Rating Data

# %%
#This line initializes an empty dictionary to store the mapping between CSV IDs and book IDs.
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %% [markdown]
# ### Finding users who like the same books as us

# %% [markdown]
# > This code is essentially counting how many times each user has interacted with books that are in the liked_books list, and it stores this information in the overlap_users dictionary. The dictionary keys are user IDs, and the values are the corresponding counts of interactions.

# %%
overlap_users = {}

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break

        user_id, csv_id, _, rating, _ = line.strip().split(",")

        # Check if csv_id is in the dictionary; if not, set book_id to None
        book_id = csv_book_mapping.get(csv_id)

        if book_id is not None and book_id in liked_books:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 28187

# %% [markdown]
# - only selects those users whose taste matches with 20% of our liked books

# %%
filtered_overlap_users = set(user_id for user_id, count in overlap_users.items() if count > len(liked_books)/5)

# %% [markdown]
# ### Finding What those users liked

# %% [markdown]
# If the user is in the filtered set, it retrieves the corresponding book_id from the csv_book_mapping dictionary and appends a list containing [user_id, book_id, rating] to the interactions_list

# %%
interactions_list = []

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")

        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 23388763

# %%
import pandas as pd 
recs = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)
recs["user_id"] = recs["user_id"].astype(str)
recs["rating"] = pd.to_numeric(recs["rating"])

# %% [markdown]
# > These steps are often done when working with collaborative filtering or recommendation systems. The categorical codes are used to represent users and books with numerical indices, which can be more efficient for certain algorithms and analyses.

# %%
# This line creates a new column "user_index" in the recs DataFrame, which represents the categorical codes assigned to each unique user ID.
recs["user_index"] = recs["user_id"].astype("category").cat.codes

# %%
recs["book_index"] = recs["book_id"].astype("category").cat.codes

# %%
len(recs["user_index"].unique())
len(recs["book_index"].unique())
# Out:
# 1368559

# %% [markdown]
# > sparse matrix where rows correspond to users, columns correspond to books, and the matrix elements represent the ratings given by users to books. Sparse matrices are particularly useful when dealing with large datasets where most entries are zero, as they save memory by only storing the non-zero elements.

# %%
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((recs["rating"], (recs["user_index"], recs["book_index"])))

ratings_mat_coo
# Out:
# <28187x1368559 sparse matrix of type '<class 'numpy.int64'>'
# 	with 23388763 stored elements in COOrdinate format>

# %%
# Conversion to coordinate format
# CSR format is efficient for arithmetic operations and slicing along rows, which are common tasks in recommendation systems and collaborative filtering algorithms.
ratings_mat = ratings_mat_coo.tocsr()

# %%
top_recs = recs["book_id"].value_counts().head(10)
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
all_recs = recs["book_id"].value_counts()
all_recs
# Out:
# book_id
# 31463       19415
# 4671        18805
# 2657        18627
# 1885        18238
# 5470        17092
#             ...
# 9743169         1
# 1277950         1
# 936909          1
# 5986621         1
# 17138312        1
# Name: count, Length: 1368559, dtype: int64

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]
all_recs
# Out:
#           book_id  book_count
# 0           31463       19415
# 1            4671       18805
# 2            2657       18627
# 3            1885       18238
# 4            5470       17092
# ...           ...         ...
# 1368554   9743169           1
# 1368555   1277950           1
# 1368556    936909           1
# 1368557   5986621           1
# 1368558  17138312           1
#
# [1368559 rows x 2 columns]

# %%
all_recs = all_recs.merge(books_titles, how = "inner", on = "book_id")
all_recs
# Out:
#          book_id  book_count  \
# 0          31463       19415
# 1           4671       18805
# 2           2657       18627
# 3           1885       18238
# 4           5470       17092
# ...          ...         ...
# 366962  18756007           1
# 366963  15720601           1
# 366964  29913659           1
# 366965  30061066           1
# 366966  34802812           1
#
#                                                     title  ratings  \
# 0                              Far from the Madding Crowd    89085
# 1                                        The Great Gatsby  2758812
# 2                                   To Kill a Mockingbird  3255518
# 3                                     Pride and Prejudice  2078406
# 4                                                    1984  2023937
# ...                                                   ...      ...
# 366962                                       The Betrayer      591
# 366963     More than a Governess (The Wetherby Brides #2)      285
# 366964         With Deadly Intent (North East Police, #1)      248
# 366965                                          Forgotten      196
# 366966  Darkness Begins: A Post-Apocalyptic Survival T...      555
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/31463.Far_...
# 1       https://www.goodreads.com/book/show/4671.The_G...
# 2       https://www.goodreads.com/book/show/2657.To_Ki...
# 3       https://www.goodreads.com/book/show/1885.Pride...
# 4           https://www.goodreads.com/book/show/5470.1984
# ...                                                   ...
# 366962  https://www.goodreads.com/book/show/18756007-t...
# 366963  https://www.goodreads.com/book/show/15720601-m...
# 366964  https://www.goodreads.com/book/show/29913659-w...
# 366965  https://www.goodreads.com/book/show/30061066-f...
# 366966  https://www.goodreads.com/book/show/34802812-d...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1388279695m...
# 1       https://images.gr-assets.com/books/1490528560m...
# 2       https://images.gr-assets.com/books/1361975680m...
# 3       https://images.gr-assets.com/books/1320399351m...
# 4       https://images.gr-assets.com/books/1348990566m...
# ...                                                   ...
# 366962  https://s.gr-assets.com/assets/nophoto/book/11...
# 366963  https://images.gr-assets.com/books/1340562868m...
# 366964  https://s.gr-assets.com/assets/nophoto/book/11...
# 366965  https://images.gr-assets.com/books/1462017262m...
# 366966  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                                 mod_title
# 0                              far from the madding crowd
# 1                                        the great gatsby
# 2                                   to kill a mockingbird
# 3                                     pride and prejudice
# 4                                                    1984
# ...                                                   ...
# 366962                                       the betrayer
# 366963        more than a governess the wetherby brides 2
# 366964             with deadly intent north east police 1
# 366965                                          forgotten
# 366966  darkness begins a postapocalyptic survival thr...
#
# [366967 rows x 7 columns]

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])
all_recs.sort_values("score", ascending=False).head(10)
popular_recs = all_recs[all_recs["book_count"] > 75].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'cover_image' : show_image, 'url': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f87c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f87c_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_4f87c_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_4f87c_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_4f87c_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_4f87c_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_4f87c_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_4f87c_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_4f87c_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f87c_level0_row0" class="row_heading level0 row0" >96</th>
#       <td id="T_4f87c_row0_col0" class="data row0 col0" >19089</td>
#       <td id="T_4f87c_row0_col1" class="data row0 col1" >7708</td>
#       <td id="T_4f87c_row0_col2" class="data row0 col2" >Middlemarch</td>
#       <td id="T_4f87c_row0_col3" class="data row0 col3" >98029</td>
#       <td id="T_4f87c_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show
row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/24493732-solutions-and-other-problems">Goodreads</a></td>
#       <td id="T_4f87c_row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1433828491m/24493732.jpg" width=50></img></td>
#       <td id="T_4f87c_row4_col6" class="data row4 col6" >solutions and other problems</td>
#       <td id="T_4f87c_row4_col7" class="data row4 col7" >535.715569</td>
#     </tr>
#     <tr>
#       <th id="T_4f87c_level0_row5" class="row_heading level0 row5" >183</th>
#       <td id="T_4f87c_row5_col0" class="data row5 col0" >337113</td>
#       <td id="T_4f87c_row5_col1" class="data row5 col1" >5704</td>
#       <td id="T_4f87c_row5_col2" class="data row5 col2" >The Tenant of Wildfell Hall</td>
#       <td id="T_4f87c_row5_col3" class="data row5 col3" >61479</td>
#       <td id="T_4f87c_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/337113.The_Tenant_of_Wildfell_Hall">Goodreads</a></td>
#       <td id="T_4f87c_row5_col5" class="data row5 col5" ><img src="https://images.gr-assets.com/books/1479652419m/337113.jpg" width=50></img></td>
#       <td id="T_4f87c_row5_col6" class="data row5 col6" >the tenant of wildfell hall</td>
#       <td id="T_4f87c_row5_col7" class="data row5 col7" >529.215114</td>
#     </tr>
#     <tr>
#       <th id="T_4f87c_level0_row6" class="row_heading level0 row6" >5919</th>
#       <td id="T_4f87c_row6_col0" class="data row6 col0" >26032825</td>
#       <td id="T_4f87c_row6_col1" class="data row6 col1" >458</td>
#       <td id="T_4f87c_row6_col2" class="data row6 col2" >The Cruel Prince (The Folk of the Air, #1)</td>
#       <td id="T_4f87c_row6_col3" class="data row6 col3" >400</td>
#       <td id="T_4f87c_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/26032825-the-cruel-prince">Goodreads</a></td>
#       <td id="T_4f87c_row6_col5" class="data row6 col5" ><img src="https://images.gr-assets.com/books/1493047153m/26032825.jpg" width=50></img></td>
#       <td id="T_4f87c_row6_col6" class="data row6 col6" >the cruel prince the folk of the air 1</td>
#       <td id="T_4f87c_row6_col7" class="data row6 col7" >524.410000</td>
#     </tr>
#     <tr>
#       <th id="T_4f87c_level0_row7" class="row_heading level0 row7" >118</th>
#       <td id="T_4f87c_row7_col0" class="data row7 col0" >5890</td>
#       <td id="T_4f87c_row7_col1" class="data row7 col1" >7007</td>
#       <td id="T_4f87c_row7_col2" class="data row7 col2" >The Woman in White</td>
#       <td id="T_4f87c_row7_col3" class="data row7 col3" >94556</td>
#       <td id="T_4f87c_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/5890.The_Woman_in_White">Goodreads</a></td>
#       <td id="T_4f87c_row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1295661017m/5890.jpg" width=50></img></td>
#       <td id="T_4f87c_row7_col6" class="data row7 col6" >the woman in white</td>
#       <td id="T_4f87c_row7_col7" class="data row7 col7" >519.248371</td>
#     </tr>
#     <tr>
#       <th id="T_4f87c_level0_row8" class="row_heading level0 row8" >260</th>
#       <td id="T_4f87c_row8_col0" class="data row8 col0" >31173</td>
#       <td id="T_4f87c_row8_col1" class="data row8 col1" >4665</td>
#       <td id="T_4f87c_row8_col2" class="data row8 col2" >Villette</td>
#       <td id="T_4f87c_row
